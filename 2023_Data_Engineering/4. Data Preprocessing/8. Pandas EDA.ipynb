# %% [markdown]
# ## 데이터 이해

# %% [markdown]
# ### 데이터 종류
# >정형 데이터, 반정형 데이터, 비정형 데이터
# >스키마 : 데이터의 구조와 제약 조건에 대한 것들을 정의한 것

# %% [markdown]
# #### 정형 데이터 (Structured Data)
# >고정된 필드에 저장된 데이터. ex. 스프레드시트

# %% [markdown]
# #### 반정형 데이터 (Semi-Structured Data)
# >고정된 필드에 저장되어 있지는 않지만, 메타데이터나 스키마를 포함하는 데이터. ex. HTML, XML, JSON, 이메일 등

# %% [markdown]
# #### 비정형 데이터 (Unstructured Data)
# >고정된 필드에 저장되어 있지 않은 데이터  ex) 텍스트, 이미지, 동영상, 음성 데이터 등

# %% [markdown]
# ### 데이터 유형
#
# ![image.png](attachment:image-2.png)

# %% [markdown]
# #### 수치형 데이터
# > 수치를 값으로 가져 수학적인 활용이 가능하다. 실수형으로 표현이 가능하다.
# > ex. 나이, 키, 온도 등
#
# - 연속형 데이터 : 더 작은 값으로 쪼갤 수 있다.
# - 이산형 데이터 : 작은 값으로 쪼개는 것이 의미가 없다.

# %% [markdown]
# #### 범주형 데이터
# > 범주 또는 그룹으로 나타내는 데이터
# > ex. 교과목 성적, 성별, 영화 별점, 우편번호 등
#
# - 순서형 데이터 : 순서 관계가 있는 범주형 데이터
# - 명목형 데이터 : 순서 관계가 없는 범주형 데이터

# %% [markdown]
# ## EDA (Exploratory Data Analysis)
# > 탐색적 데이터 분석
# > 데이터를 분석하고 결과를 도출하는 과정에 있어서 지속적으로 해당 데이터에 대한 탐색과 이해를 기본적으로 가져야 한다는 의미

# %% [markdown]
# ### 분석방법

# %% [markdown]
# #### 상관계수
# > 두 변수 x, y 사이의 상관관계의 정도를 나타내는 수치
#
# - 상관계수의 특징
#     - 상관계수 r은 -1과 1 사이에 있다.
#     - 상관계수의 절대값의 크기는 직선관계에 가까운 정도를 나타낸다.
#     - 상관계수가 0에 가까울수록 관계가 없다.
#     - 상관관계의 부호는 관계의 방향을 나타낸다.
#     - 큰 상관계수값이 항상 두 변수 사이의 인과관계를 의미하지는 않는다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 왜도
# > DataFrame.skew()를 이용하여 확인할 수 있다.
# - -0.5와 0.5사이 : 상당히 대칭적
# - -1과 1사이 : 조금 치우침
# - -1과 1 바깥 : 많이 치우침
# - 정규분포와 같이 좌우 대칭인경우 왜도가 0에 가까워진다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 첨도
# >DataFrame.kurt()로 확인할 수 있다.
# - 관측치들이 얼마나 집중적으로 중심에 몰려있는지 측정 시 사용
# - kurt 값이 0보다 작을 경우 정규분포보다 더 완만하고 납작한 분포
# - kurt 값이 0보다 크면 정규분포보다 더 뾰족한 분포
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 이상치
# > 데이터에 이상치가 있는지 박스플롯을 통해 확인
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 데이터 로드

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("titanic")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# #### 컬럼명 소문자로 변환

# %%
# df.colums의 출력값이 리스트 형태이므로 리스트에 저장해준다
df.columns = [col.lower() for col in df.columns]
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.columns = ['age', 'sibsp', 'survived', 'pclass', 'sex', 'parch', 'fare',
       'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
       'alive', 'alone']
df.columns
# Out:
# Index(['age', 'sibsp', 'survived', 'pclass', 'sex', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          891 non-null    int64
#  1   sibsp        891 non-null    int64
#  2   survived     891 non-null    object
#  3   pclass       714 non-null    float64
#  4   sex          891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# ### 수치형 데이터 분석

# %%
df_number = df.select_dtypes(include=np.number)
df_number.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   age       714 non-null    float64
#  3   sibsp     891 non-null    int64
#  4   parch     891 non-null    int64
#  5   fare      891 non-null    float64
# dtypes: float64(2), int64(4)
# memory usage: 41.9 KB

# %%
df_number.head()
# Out:
#    survived  pclass   age  sibsp  parch     fare
# 0         0       3  22.0      1      0   7.2500
# 1         1       1  38.0      1      0  71.2833
# 2         1       3  26.0      0      0   7.9250
# 3         1       1  35.0      1      0  53.1000
# 4         0       3  35.0      0      0   8.0500

# %% [markdown]
# #### 통계적 분석

# %%
df_number.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ##### age 통계적 분석

# %%
df_number['age'].sum() # 총합
# Out:
# 21205.17

# %%
df_number['age'].mean() # 평균
# Out:
# 29.69911764705882

# %%
df_number['age'].median() # 중앙값
# Out:
# 28.0

# %%
df_number['age'].var() # 분산
# Out:
# 211.01912474630802

# %%
df_number['age'].std() # 표준편차
# Out:
# 14.526497332334042

# %%
df_number['age'].min() # 최솟값
# Out:
# 0.42

# %%
df_number['age'].max() # 최댓값
# Out:
# 80.0

# %%
df_number['age'].quantile([0.25, 0.5, 0.75]) # 분위수 계산
# Out:
# 0.25    20.125
# 0.50    28.000
# 0.75    38.000
# Name: age, dtype: float64

# %% [markdown]
# #### 첨도 분석

# %%
# 첨도가 0보다 크므로 많이 치우쳤다는 것을 알 수 있다. 
df_number['fare'].kurt()
# Out:
# 33.39814088089868

# %%
df_number['fare'].plot.hist(bins=20)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
# diff() : 한 객체 내에서 열과 열 / 행과 행의 차이를 출력하는 메서드 
df_number['fare'].diff().hist(bins=20)
# Out:
# <AxesSubplot: >

# %% [markdown]
# #### 왜도 분석

# %%
df_number['fare'].mean(), df_number['fare'].median(), df_number['fare'].mode()
# Out:
# (32.204207968574636,
#  14.4542,
#  0    8.05
#  Name: fare, dtype: float64)

# %%
# 1 이상이므로 많이 치우친 데이터라는 것을 알 수 있다. 평균이 중앙값보다 크다.
df_number['fare'].skew()
# Out:
# 4.787316519674893

# %%
df_number['fare'].plot.hist(bins=20)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df_number['fare'].diff().hist(bins=20)
# Out:
# <AxesSubplot: >

# %% [markdown]
# #### 이상치 분석

# %%
sns.boxplot(y=df_number['age'], data=df)
# Out:
# <AxesSubplot: ylabel='age'>

# %%
sns.boxplot(data=df, x=df['survived'], y=df['age'])
# Out:
# <AxesSubplot: xlabel='survived', ylabel='age'>

# %% [markdown]
# #### 상관관계 분석

# %%
df_number.corr()
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
df_number.plot(kind='scatter', x='pclass', y='fare')
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='fare'>

# %%
df_number.plot(kind="scatter", x='age', y='fare')
# Out:
# <AxesSubplot: xlabel='age', ylabel='fare'>

# %%
# 상관관계를 파악할 때는 히트맵을 주로 사용한다. 
sns.heatmap(df_number.corr(), vmin=-1, vmax=1, annot=True, linewidths=0.2, cmap='Reds')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### 범주형 데이터 분석

# %%
# 숫자가 아닌 데이터를 모두 불러온다. 
df_object = df.select_dtypes(exclude=np.number)

# %%
# survived column을 불러와 데이터 타입을 object로 변경한다. 
df_object = df_object.join(df_number['survived'])
df_object['survived'] = df_object['survived'].astype('object')
df_object.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sex          891 non-null    object
#  1   embarked     889 non-null    object
#  2   class        891 non-null    category
#  3   who          891 non-null    object
#  4   adult_male   891 non-null    bool
#  5   deck         203 non-null    category
#  6   embark_town  889 non-null    object
#  7   alive        891 non-null    object
#  8   alone        891 non-null    bool
#  9   survived     891 non-null    object
# dtypes: bool(2), category(2), object(6)
# memory usage: 45.8+ KB

# %% [markdown]
# #### 통계적 분석

# %%
df_object.describe() # deck 값에 null이 많다는 것을 캐치했는가?
# Out:
#          sex embarked  class  who adult_male deck  embark_town alive alone  \
# count    891      889    891  891        891  203          889   891   891
# unique     2        3      3    3          2    7            3     2     2
# top     male        S  Third  man       True    C  Southampton    no  True
# freq     577      644    491  537        537   59          644   549   537
#
#         survived
# count        891
# unique         2
# top            0
# freq         549

# %% [markdown]
# ##### embarked 통계적 분석

# %%
# 고유값 개수
df_object['embarked'].nunique()
# Out:
# 3

# %%
# 고유값
df_object['embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
# 최빈값
df_object['embarked'].mode()
# Out:
# 0    S
# Name: embarked, dtype: object

# %%
# 범주별 개수 카운트
df_object['embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
# 범주별 비율
df_object['embarked'].value_counts(normalize=True)
# Out:
# S    0.724409
# C    0.188976
# Q    0.086614
# Name: embarked, dtype: float64

# %% [markdown]
# #### 교차 분석
#
# [pd.crosstab(index, columns, values=None, rownames=None, colnames=None, aggfunc=None, margins=False, margins_name='All', dropna=True, normalize=False)](https://pandas.pydata.org/docs/reference/api/pandas.crosstab.html)
# - index: 행으로 그룹화할 값
# - columns: 열로 그룹화할 값
# - rownames: 행 이름
# - colnames: 열 이름
# - values: 두 행/열에 따라 집계할 값(반드시 aggfunc와 함께 사용)
# - aggfunc: 집계 함수(mean, sum 등)
# - margins: True인 경우, 행/열의 소계값이 함게 산출
# - dropna: NaN을 포함하지 않고 반환(디폴트: True)
# - normalize: 개수가 아닌 비율로 표시
#   - index: 행을 기준으로 비율 표시
#   - columns: 열을 기준으로 비율 표시
#   - all: 전체 기준으로 비율 표시

# %%
# margin을 사용해서 행/열의 소계값을 함께 산출 
pd.crosstab(df_object["sex"], df_object['survived'], margins=True)
# Out:
# survived    0    1  All
# sex
# female     81  233  314
# male      468  109  577
# All       549  342  891

# %%
# 전체 기준 데이터 비율
pd.crosstab(df_object['sex'], df_object['survived'], margins=True, normalize="all")
# Out:
# survived         0         1       All
# sex
# female    0.090909  0.261504  0.352413
# male      0.525253  0.122334  0.647587
# All       0.616162  0.383838  1.000000

# %%
# 인덱스 기준 데이터 비율 
pd.crosstab(df_object['sex'], df_object['survived'], margins=True, normalize='index')
# Out:
# survived         0         1
# sex
# female    0.257962  0.742038
# male      0.811092  0.188908
# All       0.616162  0.383838

# %%
# margin을 빼면 소계 값이 산출되지 않는다. 
pd.crosstab(df_object['sex'], df_object['survived'], normalize='index')
# Out:
# survived         0         1
# sex
# female    0.257962  0.742038
# male      0.811092  0.188908

# %%
# column 기준 데이터 비율
pd.crosstab(df_object['sex'], df_object['survived'], margins=True, normalize='columns')
# Out:
# survived         0         1       All
# sex
# female    0.147541  0.681287  0.352413
# male      0.852459  0.318713  0.647587

# %%
pd.crosstab(df_object['sex'], df_object['survived'], normalize='columns')
# Out:
# survived         0         1
# sex
# female    0.147541  0.681287
# male      0.852459  0.318713

# %% [markdown]
# ### pivot table 분석

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df_pivot = pd.pivot_table(df, # 피벗할 데이터 프레임
        index='pclass', # 행 위치에 들어갈 열
        columns='sex', # 열 위치에 들어갈 열 
        values='survived', # 데이터로 사용할 값, 중요하게 생각하는 데이터를 할당
        aggfunc=['mean','sum']) # 데이터 집계 함수 

df_pivot
# Out:
#             mean              sum
# sex       female      male female male
# pclass
# 1       0.968085  0.368852     91   45
# 2       0.921053  0.157407     70   17
# 3       0.500000  0.135447     72   47

# %%
# 다중 할당도 가능하다. 
df_pivot = pd.pivot_table(df,
                    index=['pclass', 'sex'],
                    columns='survived',
                    values=['age', 'fare'],
                    aggfunc=['mean', 'max'])
df_pivot
# Out:
#                     mean                                      max        \
#                      age                   fare               age
# survived               0          1           0           1     0     1
# pclass sex
# 1      female  25.666667  34.939024  110.604167  105.978159  50.0  63.0
#        male    44.581967  36.248000   62.894910   74.637320  71.0  80.0
# 2      female  36.000000  28.080882   18.250000   22.288989  57.0  55.0
#        male    33.369048  16.022000   19.488965   21.095100  70.0  62.0
# 3      female  23.818182  19.329787   19.773093   12.464526  48.0  63.0
#        male    27.255814  22.274211   12.204469   15.579696  74.0  45.0
#
#
#                  fare
# survived            0         1
# pclass sex
# 1      female  151.55  512.3292
#        male    263.00  512.3292
# 2      female   26.00   65.0000
#        male     73.50   39.0000
# 3      female   69.55   31.3875
#        male     69.55   56.4958

# %% [markdown]
# ## 연습 문제

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
c1 = df['survived'] == 1
c2 = df['sex'] == 'female'
c3 = df['age']//10 == 2
con = c1 & c2 & c3

df_tmp = df.loc[con]
df_tmp.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 53         1       2  female  29.0      1      0  26.0000        S  Second
# 56         1       2  female  21.0      0      0  10.5000        S  Second
# 66         1       2  female  29.0      0      0  10.5000        S  Second
#
#       who  adult_male deck  embark_town alive  alone
# 2   woman       False  NaN  Southampton   yes   True
# 8   woman       False  NaN  Southampton   yes  False
# 53  woman       False  NaN  Southampton   yes  False
# 56  woman       False  NaN  Southampton   yes   True
# 66  woman       False    F  Southampton   yes   True

# %%
df_tmp[['survived', 'sex', 'age']].describe(include='all')
# Out:
#         survived     sex        age
# count       52.0      52  52.000000
# unique       NaN       1        NaN
# top          NaN  female        NaN
# freq         NaN      52        NaN
# mean         1.0     NaN  24.615385
# std          0.0     NaN   2.521701
# min          1.0     NaN  21.000000
# 25%          1.0     NaN  22.000000
# 50%          1.0     NaN  24.000000
# 75%          1.0     NaN  27.000000
# max          1.0     NaN  29.000000

# %%
con2 = ~c1 & ~c2 & ~c3

# 방법 1
df1 = df.loc[con2]
df1[['survived', 'sex', 'age']].describe(include='all')
# Out:
#         survived   sex         age
# count      345.0   345  237.000000
# unique       NaN     1         NaN
# top          NaN  male         NaN
# freq         NaN   345         NaN
# mean         0.0   NaN   35.375527
# std          0.0   NaN   15.960236
# min          0.0   NaN    1.000000
# 25%          0.0   NaN   19.000000
# 50%          0.0   NaN   35.000000
# 75%          0.0   NaN   45.500000
# max          0.0   NaN   74.000000

# %%
con2 = ~c1 & ~c2 & ~c3

# 방법 2
df2 = df_tmp.loc[con2]
df2.count()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64
